# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(''), os.path.pardir)))
from utils.plotter import visualize_classifier_data

# %%
visualize_classifier_data('/disk/10tb/home/shmelev/GENLINK/downstream_tasks/runs/real_data_real_masks', 
                          sort_bars=True, 
                          annotate=True, 
                          mask_percent='real_masks', 
                          fig_path='/disk/10tb/home/shmelev/GENLINK/pictures/supplementary_pictures/',
                          fig_size=(14, 6),
                          bar_annotation_size=18,
                          std_annotation_size=18) # (16, 6)
# Out:
# classifiers 9 9
# /disk/10tb/home/shmelev/GENLINK/utils/plotter.py:203: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar_plot.set_xticklabels(df.Classifier)
# classifiers 9 9
# /disk/10tb/home/shmelev/GENLINK/utils/plotter.py:203: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar_plot.set_xticklabels(df.Classifier)
